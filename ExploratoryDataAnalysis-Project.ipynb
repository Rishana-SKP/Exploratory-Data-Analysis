# %% [markdown]
# <h1 align="center"><font color='Red'>Exploratory Data Analysis (EDA)</font></h1>

# %% [markdown]
# <h2 align="center"> <font color='ORANGE'>AIM OF PROJECT</font></h2>

# %% [markdown]
# <i>Providing a dataset of employees working in ABC company. It consists of 458 rows and 9 columns. The company needs the detailed report and explanation of their employees in each team.To explore the dataset and it's different features & understand the relationship between the different varaibles</i>

# %% [markdown]
# #### <b><font color='brown'>EXPLORATORY DATA ANALYSIS:</font></b>

# %% [markdown]
# Exploratory Data Analysis is an initial process of analysis, in which we can summarize characteristics of data such as pattern, trends, outliers, and hypothesis testing using descriptive statistics and visualization.

# %% [markdown]
# #### <b><font color='brown'>LIBRARIES USED:</font></b>

# %% [markdown]
# Pandas, NumPy, Matplotlib, Seaborn

# %% [markdown]
# #### <b><font color='brown'>IMPORTING MODULES:</font></b>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### <b><font color='brown'>LOADING DATASET:</font></b>

# %%
#Here we use 'read_csv' function to load up our data from a CSV file
df=pd.read_csv('myexcel.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# <h2 align="center"> <font color='green'>EXPLORATORY DATA ANALYSIS</font></h2>

# %% [markdown]
# The first step in my analysis was to gain a broad overview of the dataset. Exploring the dataset to understand its structure, identify missing values, outliers, and perform data cleaning if needed.

# %%
#to display concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
#To display the initial rows
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#To display the final rows of the DataFrame
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
#To display the records present in the DataFrame
df.shape
# Out:
# (458, 9)

# %%
#To display column labels of DataFrame
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
#To display the statistics for numerical columns within the DataFrame
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
#To explore the uniqueness and distribution of values in categorical variables
df.nunique()
# Out:
# Name        458
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %%
#To remove any duplicate records
df=df.drop_duplicates()
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Handling Missing Data:

# %%
#Checking is there any null value
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
#Checking is there any null value
df.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %% [markdown]
# <b>Here it's evident that null values in the college column should be replaced with categorical data, while null values in the salary column should be replaced with numerical data.</b>

# %%
#Replacing null value of College with 'UNKNOWN'
df['College'] =df['College'].fillna('Unknown')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Replacing null value of Salary with 0
df['Salary'] =df['Salary'].fillna(0)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#all null value are replaced
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# ### Handling mismatch data:

# %%
df.Height
# Out:
# 0      06-Feb
# 1      06-Jun
# 2      06-May
# 3      06-May
# 4      06-Oct
#         ...
# 453    06-Mar
# 454    06-Jan
# 455    07-Mar
# 456       7-0
# 457    07-Mar
# Name: Height, Length: 458, dtype: object

# %% [markdown]
# <b>It appears that the "Height" column contains a combination of numeric and non-numeric values, with inconsistent formatting—some values follow the MM-Abb format, indicating the month and an abbreviation, while others use the N-N numeric format. </b>

# %%
#if any value in the 'Height' column cannot be converted to a numeric format, it will be replaced with NaN 
df['Height'] = pd.to_numeric(df['Height'], errors='coerce')

# %%
#replacing the value of height into a random number between 150 and 180
df['Height'] = np.random.randint(150, 181, size=len(df))
df.Height
# Out:
# 0      177
# 1      158
# 2      154
# 3      172
# 4      162
#       ...
# 453    166
# 454    167
# 455    151
# 456    156
# 457    157
# Name: Height, Length: 458, dtype: int32

# %% [markdown]
# ### <font color='brown'>1.Number of Employees in each Team and the percentage splitting with respect to the total employees.</font>

# %%
#Number of employees in each team
Count=df['Team'].value_counts()
Count
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
#Percentage splitting
Count=df['Team'].value_counts()
Total_employes=len(df)
percentage=(Count/Total_employes)*100
percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
#Visual Representation in the bar chart
plt.bar(Count.index,Count.values,color='green',width=0.5)
# Customize the plot
plt.xlabel('Team')
plt.ylabel('Percentage')
plt.title('Percentage Splitting of Employees in each Team')
plt.xticks(rotation='vertical')
plt.show()

# %%
#plot Pie chart
Count.plot(kind='pie')

#Add Title
plt.title('Percentage Split by Team')
plt.show()

# %% [markdown]
# <b>Upon reviewing the bar chart & pie chart, it's evident that the New Orleans Pelicans have a notably higher percentage split compared to other team members. Additionally, 23 teams exhibit an identical percentage split in the analysis.</b>

# %% [markdown]
# ### <font color='brown'>2.Segregate the employees w.r.t different positions</font>

# %%
# Segregate employees based on positions
position=df['Position'].value_counts()
position
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#Visual Representation in the bar chart
plt.bar(position.index,position.values,color='blue',width=0.5)
# Customize the plot
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.title('Employees based on different position')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <b>The data's value counts and corresponding bar chart reveal that the largest employee segment corresponds to the 'SG' position, slightly exceeding 100 individuals, followed by the 'PF' position as the second most populous, with the 'C' position hosting the fewest employees.</b>

# %% [markdown]
# ### <font color='brown'>3.Age group that most of the employees belongs to.</font>

# %%
age=df['Age'].value_counts()

# %%
# Most Common Age group
(pd.cut(df['Age'],bins=[10,20,30,40],labels=['10-20','20-30','30-40'])).value_counts()
# Out:
# Age
# 20-30    346
# 30-40     91
# 10-20     21
# Name: count, dtype: int64

# %%
#Visual representation using histogram
plt.figure(figsize=(12,6))
plt.hist(df['Age'],edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Employees')
plt.show()

# %% [markdown]
# <b>As per the histogram analysis, a significant concentration of employees is evident within the age group of 20 to 30 years. Notably, there's a striking absence of individuals above 40 years old, while a comparatively smaller proportion is observed within the 10 to 20 age range.</b>

# %% [markdown]
# ### <font color='brown'>4.Find out under which team and position, spending in terms of salary is high.</font>

# %%
High_Salary=df.groupby(['Team','Position'])['Salary'].sum()
High_Salary
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %% [markdown]
# <b>df.groupby(['Team','Position'])['Salary'].sum() is performing a group-by operation on a DataFrame. It's grouping the data by two columns: 'Team' and 'Position'. Then, it selects the 'Salary' column and computes the sum of salaries for each unique combination of 'Team' and 'Position'. Essentially, it calculates the total salary for each team-position pair.
#
# High_Salaye stores the result of the above operation. It likely contains a Pandas Series or DataFrame with the total salaries for each unique team-position combinati</b>on

# %%
team_highest_salary=High_Salary.idxmax()
team_highest_salary
# Out:
# ('Los Angeles Lakers', 'SF')

# %% [markdown]
# <b> idxmax() function is used to returns the index (or row label) where the maximum value occurs in the High_Salary Series or DataFrame.Hence it finds the team-position combination that has the highest total salary.</b>

# %%
highest_salary_amount=High_Salary.max()
highest_salary_amount
# Out:
# 31866445.0

# %% [markdown]
# <b>max() function retrieves the maximum value from the High_Salary Series or DataFrame. Hence it finds the highest total salary among all team-position combinations.</b>

# %%
High_Salary.index
# Out:
# MultiIndex([(     'Atlanta Hawks',  'C'),
#             (     'Atlanta Hawks', 'PF'),
#             (     'Atlanta Hawks', 'PG'),
#             (     'Atlanta Hawks', 'SF'),
#             (     'Atlanta Hawks', 'SG'),
#             (    'Boston Celtics',  'C'),
#             (    'Boston Celtics', 'PF'),
#             (    'Boston Celtics', 'PG'),
#             (    'Boston Celtics', 'SF'),
#             (    'Boston Celtics', 'SG'),
#             ...
#             (         'Utah Jazz',  'C'),
#             (         'Utah Jazz', 'PF'),
#             (         'Utah Jazz', 'PG'),
#             (         'Utah Jazz', 'SF'),
#             (         'Utah Jazz', 'SG'),
#             ('Washington Wizards',  'C'),
#             ('Washington Wizards', 'PF'),
#             ('Washington Wizards', 'PG'),
#             ('Washington Wizards', 'SF'),
#             ('Washington Wizards', 'SG')],
#            names=['Team', 'Position'], length=149)

# %%
High_Salary.values
# Out:
# array([22756250., 23952268.,  9763400.,  6000000., 10431032.,  7351395.,
#        18170960., 19898606.,  6796117.,  6323990., 20636276., 14304819.,
#         8747276.,  8840104., 20316720., 14057310., 14328455.,  6331404.,
#        23307031., 20848760., 16805037., 22343064.,  3916320., 22870197.,
#        20486870., 27882029., 19654777., 23917776., 15047237.,  6996057.,
#        12211340., 17672733., 16462102., 17856500.,  4851719., 14049955.,
#        10447240., 27982771.,  2790245., 12272091.,  8000000., 17040012.,
#        20694400.,  9161760., 19623748., 14550625., 16914511., 18831837.,
#        18948276., 23306640.,  7020455.,  6687086., 10145957., 28122883.,
#         8000000.,  8259845., 16218770., 22873211., 11400000., 20789602.,
#        19966446., 25527217., 14651695., 13919680., 17418624.,  9012090.,
#         6473272., 31866445.,  7000000., 19688000., 22178454., 10289328.,
#        13743940., 10651158.,   981348., 31538671., 14783000., 13842502.,
# ...

# %%
#Assuming High_Salary is your MultiIndex Series and 'values' are the associated values 
#replace these variable names with your actual data

#unstack the MultiIndex Series to create a DataFrame
dframe=High_Salary.unstack()

# %%
dframe
# Out:
# Position                         C          PF          PG          SF  \
# Team
# Atlanta Hawks           22756250.0  23952268.0   9763400.0   6000000.0
# Boston Celtics           7351395.0  18170960.0  19898606.0   6796117.0
# Brooklyn Nets           20636276.0  14304819.0   8747276.0         NaN
# Charlotte Hornets       20316720.0  14057310.0  14328455.0   6331404.0
# Chicago Bulls           20848760.0  16805037.0  22343064.0   3916320.0
# Cleveland Cavaliers     20486870.0  27882029.0  19654777.0  23917776.0
# Dallas Mavericks         6996057.0  12211340.0  17672733.0  16462102.0
# Denver Nuggets           4851719.0  14049955.0  10447240.0  27982771.0
# Detroit Pistons         12272091.0   8000000.0  17040012.0  20694400.0
# Golden State Warriors   19623748.0  14550625.0  16914511.0  18831837.0
# Houston Rockets         23306640.0   7020455.0   6687086.0  10145957.0
# Indiana Pacers           8000000.0   8259845.0  16218770.0  22873211.0
# ...

# %%
#Plotting
ax=dframe.plot(kind='bar',figsize=(14,8))
ax.set_xlabel('Team')
ax.set_ylabel('Salary')
ax.set_title('Salary by Team & Position')
plt.legend(title='Position',loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>The barplot vividly illustrates that the Los Angeles Lakers spend the most in terms of salary compared to other teams.</b>

# %% [markdown]
# ### <font color='brown'>5.Find if there is any correlation between age and salary , represent it visually.</font>

# %%
#Correlation Between Age and Salary
corrltn=df[['Age','Salary']].corr()
corrltn
# Out:
#             Age   Salary
# Age     1.00000  0.20501
# Salary  0.20501  1.00000

# %%
#Plot the correlation heatmap
sns.heatmap(corrltn,annot=True,cmap='coolwarm',fmt=".2f")

#Add title
plt.title('Correlation Between Age & Salary')
plt.show()

# %% [markdown]
# <b>This correlation matrix offers a comprehensive view of the relationship between 'Age' and 'Salary', revealing the extent of their linear association; a correlation value near 1 signifies a strong positive linear correlation between these variables.|</b>

# %% [markdown]
# <b><font color='red'>Key Insights:
#
# <b>1.'New Orleans Pelicans' holds the highest count of employees among all teams, indicating a substantial workforce.
#
# <b>2.The 'SG' (Shooting Guard) position stands out with the most employees, while 'C' (Center) has the smallest count, indicating potential position-specific trends.</b>
#
# <b>3.The age bracket of 20-30 years accommodates the largest employee segment, whereas the 10-20 bracket shows the smallest count, signifying a concentration within a specific age range.</b>
#
# <b>4.Both the 'Los Angeles Lakers' team and the 'SF' (Small Forward) position demonstrate higher spending in terms of salaries, highlighted by the calculated maximum salary rows.</b>
#
# <b>5.Employees aged between 30-40 years earn the highest salaries, suggesting a salary increase with advancing age, aligning with career progression and experience.</b>
#
# </font></b>
